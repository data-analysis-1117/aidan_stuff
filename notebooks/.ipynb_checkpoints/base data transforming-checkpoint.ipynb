# %% [markdown]
# # Inspection of data

# %%
# imports
import pandas as pd

# %%
training = pd.read_csv("../data/training.csv", delimiter = ";")
holdout = pd.read_csv("../data/holdout.csv", delimiter = ";")

# %%
training.head(5)
# Out:
#    virksomhedsRegistreringsId        target  ejerkreds_aktiv_93  \
# 0                           1  target_FALSE                 NaN
# 1                           2  target_FALSE                 NaN
# 2                           5  target_FALSE                 NaN
# 3                           6   target_TRUE                 NaN
# 4                           7  target_FALSE                 NaN
#
#    ejerkreds_aktiv_92  ejerkreds_aktiv_94  virksomhedsoplysninger_17  \
# 0                   0                   0                        NaN
# 1                   0                   0                       12.0
# 2                   0                   0                        NaN
# 3                   0                   0                        NaN
# 4                   1                   1                        1.0
#
#    virksomhedsoplysninger_2  virksomhedsoplysninger_4  \
# 0                       NaN                       NaN
# ...

# %%
# target shows whether the company was created for fraudulent purposes or not
